# %% [markdown]
# Здесь создается submission для тестовых данных

# %%
import pandas as pd
from transformers import AutoModelForTokenClassification, AutoTokenizer
import torch
from tqdm import tqdm

# %% [markdown]
# Подгружаем и разархивируем дообученную модель

# %%
# !unzip -o model.zip -d ./trained_model
# Out:
# Archive:  model.zip
#    creating: ./trained_model/prosto_dataset_base/
#   inflating: ./trained_model/prosto_dataset_base/model.safetensors
#   inflating: ./trained_model/prosto_dataset_base/training_args.bin
#   inflating: ./trained_model/prosto_dataset_base/vocab.txt
#   inflating: ./trained_model/prosto_dataset_base/config.json
#   inflating: ./trained_model/prosto_dataset_base/tokenizer_config.json
#   inflating: ./trained_model/prosto_dataset_base/tokenizer.json
#   inflating: ./trained_model/prosto_dataset_base/special_tokens_map.json

# %%
model = AutoModelForTokenClassification.from_pretrained("./trained_model/prosto_dataset_base")
tokenizer = AutoTokenizer.from_pretrained("./trained_model/prosto_dataset_base")

# %%
def load_txt_to_df(file_path: str, sep: str = ",", columns=("id", "text")) -> pd.DataFrame:
    """
    Загружает txt-файл в DataFrame.
    Ожидается формат: id,text.

    Принимает:
        file_path (str): путь к txt-файлу
        sep (str): разделитель (по умолчанию ",")
        columns: имена колонок (по умолчанию ("id", "text"))

    Возвращает:
        pd.DataFrame
    """
    with open(file_path, "r", encoding="utf-8") as f:
        lines = [line.strip() for line in f]

    data = [line.split(sep, 1) for line in lines]
    df = pd.DataFrame(data, columns=columns)
    df = df.iloc[1:].reset_index(drop=True)
    return df

# %%
def restore_spaces(text, model, tokenizer, device="cuda"):
    """
    Восстанавливает пробелы в тексте по предсказаниям модели.

    Принимает:
        text (str): строка без пробелов
        model: обученная модель
        tokenizer: токенизатор
        device (str): устройство для вычислений ("cuda" или "cpu")

    Возвращает:
        str: восстановленный текст с пробелами
    """

    model.to(device)
    model.eval()

    tokens = list(text)
    enc = tokenizer(tokens, is_split_into_words=True, return_tensors="pt", truncation=True, max_length=128)
    enc = {k: v.to(device) for k, v in enc.items()}

    with torch.no_grad():
        outputs = model(**enc)
        preds = outputs.logits.argmax(-1).squeeze().tolist()

    result = ""
    for ch, p in zip(tokens, preds[:len(tokens)]):
        result += ch
        if p == 1:
            result += " "
    return result

# %% [markdown]
# Пример восстановления пробелов для запроса "Сдам квартиру"

# %%
example = restore_spaces('сдамквартиру', model, tokenizer)
print(example)
# Out:
# сдам квартиру

# %% [markdown]
# Загружаем тестовый даатсет

# %%
test_df_path = '/content/dataset_1937770_3.txt'
test_df = load_txt_to_df(test_df_path)

# %%
test_df.head(2)
# Out:
#   id                text
# 0  0     куплюайфон14про
# 1  1  ищудомвПодмосковье

# %%
# Убедимся, что модель на нужном устройстве
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)

# Создаем новый столбец с предсказанным текстом
test_df['text_spaces'] = [
    restore_spaces(text, model, tokenizer, device=device)
    for text in tqdm(test_df['text'], desc="Restoring spaces")
]
# Out:
# Restoring spaces: 100%|██████████| 1005/1005 [00:10<00:00, 99.23it/s]

# %%
test_df.head()
# Out:
#   id                           text                         text_spaces
# 0  0                куплюайфон14про                  куплю айфон 14 про
# 1  1             ищудомвПодмосковье               ищу дом в Подмосковье
# 2  2  сдаюквартирусмебельюитехникой  сдаю квартиру с мебелью и техникой
# 3  3     новыйдивандоставканедорого       новый диван доставка недорого
# 4  4                отдамдаромкошку                   отдам даром кошку

# %%
def get_space_indices(text):
    """
    Возвращает индексы всех пробелов в строке

    Принимает:
        text (str): строка с пробелами

    Возвращает:
        list[int]: список индексов (позиции символов в строке),
    """
    return [i for i, ch in enumerate(text) if ch == " "]


# Создаем новый столбец с индексами пробелов
test_df['space_pos'] = test_df['text_spaces'].apply(get_space_indices)

# %%
test_df.head()
# Out:
#   id                           text                         text_spaces  \
# 0  0                куплюайфон14про                  куплю айфон 14 про
# 1  1             ищудомвПодмосковье               ищу дом в Подмосковье
# 2  2  сдаюквартирусмебельюитехникой  сдаю квартиру с мебелью и техникой
# 3  3     новыйдивандоставканедорого       новый диван доставка недорого
# 4  4                отдамдаромкошку                   отдам даром кошку
#
#              space_pos
# 0          [5, 11, 14]
# 1            [3, 7, 9]
# 2  [4, 13, 15, 23, 25]
# 3          [5, 11, 20]
# 4              [5, 11]

# %%
test_df['text_spaces'].tolist()
# Out:
# ['куплю айфон 14 про',
#  'ищу дом в Подмосковье',
#  'сдаю квартиру с мебелью и техникой',
#  'новый диван доставка недорого',
#  'отдам даром кошку',
#  'работа в Москве удаленно',
#  'куплю телевизор Philips',
#  'ищу грузчиков для переезда',
#  'ремонт квартир под ключ',
#  'куплю ноутбук HP',
#  'ищу квартиру у метро',
#  'новая микроволновка Samsung',
#  'срочно продам велосипед',
#  'куплю гитару Fender',
#  'ищу репетитора по биологии',
#  'сдаю гараж на длительный срок',
#  'куплю диван бу',
#  'ищу мастера по ремонту холодильников',
#  'новый шкаф доставка сегодня',
#  'куплю Xbox One',
#  'ищу подработку по вечерам',
#  'сдам комнату студентке',
#  'куплю старую книгу',
#  'ищу собаку лабрадор',
#  'новый телефон Xiaomi 13',
#  'куплю Playstation 5 диск',
#  'ищу комнату в центре города',
#  'срочно нужна няня ребенку',
#  'куплю стиральную машину Indesit',
#  'ищу детскую кроватку бу',
#  'новая куртка доставка',
#  'куплю велосипед Merida',
#  'ищу врача офтальмолога',
#  'сдаю квартиру в центре Москвы',
#  'куплю холодильник Samsung',
#  'ищу кошку британскую',
#  'новый ноутбук доставка завтра',
#  'куплю шкаф бу',
#  'ищу репетитора по истории',
#  'сдаю комнату без посредников',
#  'куплю телевизор LG OLED',
#  'ищу квартиру недорого срочно',
#  'новый айфон доставка',
#  'куплю гитару Yamaha',
#  'ищу студию у метро',
#  'сдам квартиру молодоженам',
#  'куплю компьютер игровой',
#  'ищу работу поваром в кафе',
#  'новый диван Ikea',
#  'куплю старый ноутбук',
#  'ищу собаку добермана',
#  'срочно сдаю комнату',
#  'куплю монитор LG',
#  'ищу мастера по сантехнике',
#  'новый стол доставка',
#  'куплю айфон 13 мини',
#  'ищу девушку для отношений',
#  'сдаю дачу на лето',
#  'куплю стиральную машину LG',
#  'ищу учителя английского языка',
#  'новый ноутбук Asus',
#  'куплю матрас ортопедический',
#  'ищу комнату на длительный срок',
#  'сдам квартиру без залога',
#  'куплю холодильник Atlant',
#  'ищу собаку шпица',
#  'новая стиральная машина доставка',
#  'куплю телевизор Sony',
#  'ищу репетитора по географии',
#  'сдаю комнату с мебелью',
#  'куплю пылесос Dyson',
#  'ищу работу официанткой',
#  'новый шкаф купе',
#  'куплю диван угловой',
#  'ищу квартиру на длительный срок',
#  'сдам гараж в аренду',
#  'куплю велосипед Stels',
#  'ищу врача педиатра',
#  'новый телефон Oppo',
#  'куплю микроволновку Samsung',
#  'ищу комнату для девушки',
#  'срочно продам шкаф',
#  'куплю Playstation 4 slim',
#  'ищу собаку немецкую овчарку',
#  'новая куртка зима',
#  'куплю телефон Honor',
#  'ищу подругу для прогулок',
#  'сдаю квартиру семье',
#  'куплю телевизор Toshiba',
#  'ищу мастера по ремонту стиралок',
#  'новый диван серый',
#  'куплю комод бу',
#  'ищу учителя по математике',
#  'сдам квартиру студентам',
#  'куплю велосипед бу',
#  'ищу студию на месяц',
#  'новая микроволновка доставка',
#  'ищу работу на выходные',
#  'куплю телефон Huawei',
#  'продам шкаф, почти новый, с зеркалами',
#  'ищу книгу братья карамазовы, срочно',
#  'новый монитор, 27 дюймов, доставка',
#  'куплю коврик для йоги, недорого!',
#  'ищу инструктора по плаванию, бассейн рядом',
#  'сдам комнату, только девушке',
#  'куплю швейную машинку, рабочую',
#  'ищу друзей для путешествий, летом в горы',
#  'новая кофеварка Philips, гарантия есть',
#  'куплю лыжи, палки в комплекте',
#  'ищу учителя по вокалу, джаз',
#  'сдам место в гараже, сухо',
#  'куплю детский велосипед, для девочки',
#  'ищу пекаря в кафе, утро',
#  'новая стиралка Bosch, привезу сам',
#  'куплю стол письменный, белый',
#  'ищу программиста на проект, срочно!',
#  'сдам студию посуточно, метро рядом',
#  'куплю сковороду чугунную, диаметр 28',
#  'ищу репетитора по биологии, ЕГЭ',
#  'новая газовая плита, при везём быстро',
#  'куплю машину ВАЗ бу, на ходу',
#  'ищу столик для ноутбука, складной',
#  'сдам квартиру на ночь, чисто',
#  'куплю шкаф-купе, трёхдверный',
#  'ищу костюм на свадьбу, мужской',
#  'новый пылесос Samsung, коробка есть',
#  'куплю рюкзак туристический, 70 литров',
#  'ищу учителя по шахматам',
#  'сдам парковку в центре, охрана',
#  'куплю кроссовки Adidas, оригинал',
#  'ищу столярные услуги, недорого',
#  'новый телевизор LG, гарантия 2 года',
#  'куплю вазу для цветов, стеклянную',
#  'ищу уборщицу на выходные',
#  'сдам офис, 20 квадратов',
#  'куплю коньки женские, размер 37',
#  'ищу переводчика с английского',
#  'новый утюг Philips, гарантия',
#  'куплю наушники, беспроводные',
#  'ищу плиточника, ремонт ванной',
#  'сдам гараж, ключи на руках',
#  'куплю ноутбук, недорого, срочно',
#  'ищу грузчиков на завтра',
#  'новый роутер Xiaomi, вайфай 6',
#  'куплю колонки 5.1, мощные',
#  'ищу электрика, розетки и скрят!',
#  'сдам дачу на неделю, есть баня',
#  'куплю миксер кухонный, брендовый',
#  'ищу фотографа на мероприятие',
#  'новая мультиварка Redmond',
#  'куплю чайник электрический, новый',
#  'ищу пылесос, моющий',
#  'сдам кладовку, центр города',
#  'куплю камеру видеонаблюдения',
#  'ищу няню, график гибкий',
#  'новый смартфон, запечатанный',
#  'куплю чемодан на колёсах',
#  'ищу парикмахера на дом',
#  'сдам склад, 50 метров',
#  'куплю проектор, для фильмов',
#  'ищу гитариста в группу',
#  'новый кухонный комбайн',
#  'куплю диван, ткань серая',
#  'ищу плиту электрическую',
#  'сдам студию в центре, уютная',
#  'куплю мясорубку ручную',
#  'ищу шеф-повара в ресторан',
#  'новый матрас ортопедический',
#  'куплю тренажёр, вело',
#  'ищу адвоката, консультация',
#  'сдам офис, аренда помесячно',
#  'куплю картину маслом',
#  'ищу бухгалтера на полставки',
#  'новая печь микроволновая',
#  'куплю лодку резиновую',
#  'ищу логопеда, занятия дома',
#  'сдам квартиру, ремонт свежий',
#  'ищу мебельщика, кухня под заказ',
#  'новый кулер для воды',
#  'куплю стол складной',
#  'ищу водителя, ночные смены',
#  'сдам квартиру, только русским',
#  'куплю платье вечернее',
#  'ищу хирурга, консультация срочно',
#  'новый фильтр для воды',
#  'куплю кресло офисное',
#  'ищу массажиста на дом',
#  'сдам помещение под склад',
#  'куплю телефон Oppo',
#  'ищу психолога, опыт обязателен',
#  'новая колонка JBL',
#  'куплю джинсы Levi’s',
#  'ищу дом работницу, центр',
#  'сдам дом, участок 6 соток',
#  'куплю конструктор Lego',
#  'ищу художника для портрета',
#  'новый блендер, гарантия',
#  'куплю видеокамеру, недорого',
#  'ищу репетитора по химии',
#  'сдам дачу, лес рядом',
#  'куплю зимние шины',
#  'ищу гида по Москве',
#  'новая люстра потолочная',
#  'куплю ковёр, шерстяной',
#  'ищу аренду гаража',
#  'сдам квартиру с балконом',
#  'куплю удочку для рыбалки',
#  'ищу композитора, музыка',
#  'новый тостер, черный',
#  'куплю столовые приборы',
#  'ищу инженера по ремонту',
#  'сдам парковку, центр',
#  'куплю резину зимнюю',
#  'ищу актера для съемок',
#  'новая плита электрическая',
#  'куплю видеокарту RTX',
#  'ищу юриста, оформление договора',
#  'сдам склад, сухое помещение',
#  'куплю комод белый',
#  'ищу плиточника, срочно',
#  'новая лампа настольная',
#  'куплю скейтборд, новый',
#  'сдам комнату с ремонтом',
#  'куплю роутер TP-Link',
#  'ищу парня для съёмок',
#  'новый ковёр, мягкий',
#  'куплю часы Casio',
#  'ищу поставщика овощей',
#  'сдам студию, центр города',
#  'куплю пылесос моющий',
#  'ищу дизайнера интерьера',
#  'новый холодильник, белый',
#  'ищу няню, полный день',
#  'сдам квартиру с техникой',
#  'куплю плиту газовую',
#  'ищу врача кардиолога',
#  'новый чайник электрический',
#  'куплю стулья деревянные',
#  'ищу повара в кафе',
#  'сдам дом на месяц',
#  'куплю автомобиль бу',
#  'ищу программиста python',
#  'новая посудомойка Bosch',
#  'куплю камеру Canon',
#  'ищу работу бариста',
#  'сдам студию, срочно',
#  'куплю айфон 15 про',
#  'сдам квартиру в центре',
#  'ищу работу программистом',
#  'новая мебель в наличии',
#  'куплю телевизор Samsung',
#  'ищу такси до аэропорта',
#  'срочно отдам котенка',
#  'куплю холодильник бу',
#  'сдаю дачу с баней',
#  'куплю велосипед новый',
#  'ищу студию без мебели',
#  'сдам комнату на месяц',
#  'куплю монитор Samsung',
#  'ищу собаку хаски',
#  'новая куртка доставка завтра',
#  'куплю телевизор LG',
#  'ищу учителя испанского',
#  'сдам гараж срочно',
#  'куплю ноутбук Lenovo',
#  'ищу квартиру посуточно',
#  'новый столи стулья',
#  'куплю телефон Pixel',
#  'ищу врача стоматолога',
#  'сдаю офис в аренду',
#  'куплю гитару Gibson',
#  'ищу работу курьером',
#  'новый ноутбук MSI',
#  'куплю микроволновку LG',
#  'ищу девушку для прогулок',
#  'сдам склад недорого',
#  'куплю айпад бу',
#  'ищу собаку таксу',
#  'куплю компьютер Mac',
#  'ищу репетитора по физике',
#  'сдам квартиру посуточно',
#  'куплю диван кожаный',
#  'ищу работу дизайнером',
#  'новый холодильник доставка',
#  'куплю телевизор OLED',
#  'ищу студию с ремонтом',
#  'сдам комнату без мебели',
#  'куплю пылесос Xiaomi',
#  'ищу репетитора по русскому',
#  'новая мебель на заказ',
#  'куплю наушники Sony',
#  'ищу мастера по мебели',
#  'сдам дачу на лето',
#  'ищу работу тестировщиком',
#  'новый телефон Honor',
#  'куплю матрас бу',
#  'ищу собаку бигля',
#  'сдам гараж в центре',
#  'куплю ноутбук Acer',
#  'ищу студию на длительный срок',
#  'новый диван в наличии',
#  'куплю стол обеденный',
#  'ищу врача терапевта',
#  'сдаю квартиру с ремонтом',
#  'куплю миксер Bosch',
#  'ищу подработку вечером',
#  'новая куртка мужская',
#  'куплю телевизор JVC',
#  'ищу репетитора по информатике',
#  'сдам дому моря',
#  'куплю планшет Huawei',
#  'ищу работу менеджером',
#  'новый ноутбук Dell',
#  'куплю кресло компьютерное',
#  'ищу собаку джек рассел',
#  'сдам студию без посредников',
#  'куплю велосипед Giant',
#  'ищу врача хирурга',
#  'новый пылесос доставка',
#  'куплю айфон 13',
#  'сдам комнату для девушки',
#  'куплю холодильник новый',
#  'ищу работу водителем',
#  'новый диван угловой',
#  'ищу студию с мебелью',
#  'сдам дачу недорого',
#  'куплю микроволновку бу',
#  'ищу собаку пуделя',
#  'новый телевизор TCL',
#  'куплю ноутбук Asus',
#  'ищу учителя французского',
#  'ищу репетитора по алгебре',
#  'новая кухня в наличии',
#  'куплю компьютер Dell',
#  'ищу работу продавцом',
#  'куплю телевизор Sharp',
#  'ищу собаку лайку',
#  'продам диван бу',
#  '2024 год',
#  'ищу работу программистом удаленно',
#  'холодильник сломался, помогите срочно',
#  'АВТОМОЙКА РЯДОМ',
#  'телевизор LG 55',
#  'Москва Ikea доставка',
#  'срочно ищу квартиру у метро',
#  'ноутбук не включается, что делать?',
#  'новый стол Ikea доставка',
#  'продаю кошку в хорошие руки',
#  'Windows 11 не запускается',
#  'продаю Playstation 5 почти новая',
#  'квартира с ремонтом и мебелью',
#  'Avito не открывается, помогите',
#  'хочу купить велосипед бу',
#  'ищу репетитора по математике',
#  'суши доставка ночью',
#  'нужна помощь в переезде срочно',
#  'айфон 14 промакс',
#  'ищу ключи от машины',
#  'Сбербанк не работает банкомат',
#  'продаю комод буторг',
#  'куплю цветы розы тюльпаны',
#  'хочу заказать такси в аэропорт',
#  'ищу дом в деревне на лето',
#  'куплю ноутбук для игр',
#  'отдам даром старый шкаф',
#  'ищу мастера по ремонту ноутбуков',
#  'автосервис по близости',
#  'продаю iPhone XR',
#  'ищу квартиру в Москве недорого',
#  'собака потерялась на улице',
#  'ищу работу официантом вечером',
#  'подарю котенка хорошим людям',
#  'Samsung A54 новый',
#  'квартира студия долгосрочно',
#  'Иванов Иван Сергеевич',
#  'ищу автозапчасти на ВАЗ',
#  'сломался пылесос Samsung',
#  'срочно нужен мастер-сантехник',
#  'ищу дешевые авиабилеты',
#  'куплю билеты в театр',
#  'новый холодильник дешево',
#  'iPhone 15 Pro',
#  'ремонт обуви рядом',
#  'сдам комнату студенту',
#  'хочу заказать суши!',
#  'ноутбук зависает часто, что делать',
#  'Яндекс Еда не работает',
#  'ищу запчасти на ВАЗ 2107',
#  'ремонт iPhone быстро',
#  'хочу купить самокат ребенку',
#  'ищу репетитора по английскому',
#  'сдаю квартиру посуточно',
#  'доставка еды Москва',
#  'продам куртку бу',
#  'куплю колеса зима',
#  'ремонт компьютеров недорого',
#  'продаю стул Ikea',
#  'автостекло замена',
#  'нужен мастер по мебели',
#  'куплю детскую коляску',
#  'продаю Xbox Series S',
#  'хочу купить мороженое',
#  'ремонт iPhone Москва',
#  'хочу кофелатте',
#  'IKEA закрылась, что делать?',
#  'ищу подругу для общения',
#  'срочно нужен репетитор',
#  'потерял паспорт, помогите',
#  'куплю детские вещи',
#  'ремонт iPhone срочно',
#  'ищу авто с пробегом',
#  'куплю iPhone 12',
#  'новый диван доставка',
#  'квартира с ремонтом недорого',
#  'хочу купить телевизор Samsung',
#  'срочно продаю велосипед бу',
#  'ищу студента для помощи',
#  'Москва Сбербанк банкомат',
#  'ищу мебель бу недорого',
#  'ноутбук Asus ROG',
#  'хочу заказать пиццу',
#  'сдаю квартиру на месяц',
#  'ищу дешёвый телефон',
#  'продам монитор бу',
#  'ищу специалиста по ремонту',
#  'куплю гитару недорого',
#  'ищу книгу по истории',
#  'старый телевизор работает',
#  'куплю самокат детский',
#  'ищу собаку, пропала',
#  'А я танцую пьяный под дождём',
#  'Курили только сиги, если чё',
#  'Наш образ жизни станет палачом',
#  'Нисколько не жалею ни о чём',
#  'Грустно, когда расписаны все маршруты',
#  'Когда на часах важны минуты',
#  'И все на свете стало как-то скучно и глупо',
#  'Моя шиза знает, когда нажать на плей',
#  'Не жди меня родная, закрывай на замок дверь',
#  'Утро доброе, держи меня фонарь',
#  'Очки тёмные, спрячь темне глаза',
#  'Солнце яркое, прошу согрей меня',
#  'Было весело, но яб не повторял',
#  'Я календарь перевернул',
#  'И снова третье сентября',
#  'На фото я твоё взгляну',
#  'Но почему, но почему',
#  'Расстаться всё же нам пришлось?',
#  'Ведь было всё у нас всерьёз',
#  'Второго сентября',
#  'Журавлей белый клин',
#  'Твоя дочь и мой сын —',
#  'Все хотят теплоты и ласки',
#  'Мы в любовь, как в игру,',
#  'На холодном ветру',
#  'Поиграли с тобой',
#  'Но пришёл сам собой',
#  'Вы цветшая тень, выжженная на',
#  'Городском ландшафте меня зовёт',
#  'Окна янтарём лижут мне глаза',
#  'Кровь и слепота волокут вперёд',
#  'Лёгкие опухли',
#  'А морок сквозь толпу',
#  'Манит, игнорируя меня',
#  'Только бы догнал',
#  'Я его почти догнал',
#  'Тело исполняется огня',
#  'Сердце лупит мне в грудь, как в гонг',
#  'Расползаясь по сосудам раскатами',
#  'Ветхий город применяет закон',
#  'Чтобы два близнеца оказались разъятыми',
#  'Я давлюсь, изрыгая огонь',
#  'Глотками воздуха',
#  'На альвеолах распятыми',
#  'В этом стробоскопическом кино',
#  'Для достижения рубежа',
#  'Мне не хватает дыхания, но',
#  'Я продолжаю что есть мочи бежать',
#  'Только меня беспокоит одно',
#  'Лёгкие будто поела ржа',
#  'Я продолжаю за ним бежать',
#  'Я ананас, я такой же как он',
#  'Колючий внутри и со всех сторон',
#  'Не шути со мной',
#  'Я тропический лев',
#  'Аркадий Укупник — кусающий лжец',
#  'Тот, кто в пятнадцать лет убежал из дома,',
#  'Вряд ли поймет того, кто учился в спецшколе.',
#  'Тот, у кого есть хороший жизненный план,',
#  'Вряд ли будет думать о чем-то другом.',
#  'Мы пьем чай в старых квартирах,',
#  'Ждем лета в старых квартирах,',
#  'В старых квартирах, где есть свет,',
#  'Газ, телефон, горячая вода,',
#  'Радиоточка, пол-паркет,',
#  'Санузел раздельный, дом кирпичный,',
#  'Одна семья, две семьи, три семьи...',
#  'Много подсобных помещений,',
#  'Первый и последний - не предлагать,',
#  'Рядом с метро, центр...',
#  'Все говорят, что мы в-месте. ..',
#  'Все говорят, но немногие знают, в каком.',
#  'А из наших труб идет необычный дым.',
#  'Стой! Опасная зона! Работа мозга!..',
#  'Пожалуйста не умирай',
#  'Или мне придется тоже',
#  'Ты конечно сразу в рай',
#  'А я не думаю что тоже',
#  'Хочешь сладких апельсинов',
#  'Хочешь вслух рассказ длинный',
#  'Хочешь я взорву все звезды',
#  'Что мешают спать',
#  'Пожалуйста только живи',
#  'Ты же видишь я живу тобою',
#  'Моей огромной любви',
#  'Хватит нам двоим с головою',
#  'Хочешь море с парусами',
#  'Хочешь музык новых самых',
#  'Хочешь я убью соседей',
#  'Хочешь солнце вместо лампы',
#  'Хочешь за окошком Альпы',
#  'Хочешь я отдам все песни',
#  'Про тебя отдам все песни',
#  'Я искала тебя годами долгими,',
#  'Искала тебя дворами темными.',
#  'В журналах, в кино, среди друзей.',
#  'В день, когда нашла, с ума сошла.',
#  'Ты, совсем как во сне,',
#  'Совсем как в альбомах,',
#  'Где я рисовала тебя гуашью.',
#  'Дальше были звонки, ночные больше.',
#  'Слезы, нервы, любовь и стрелки в Польше.',
#  'Дети, но не мои, старые зазнобы,',
#  'Куришь каждые пять, мы устали оба.',
#  '... годами долгими.',
#  '... ночами темными.',
#  'Искала тебя дворами темными,',
#  'В журналах, в кино, годами долгими,',
#  'Искала тебя ночами, чами, чами, чами...',
#  'Большие города',
#  'Пустые поезда',
#  'Ни берега ни дна',
#  'Все начинать сначала',
#  'Холодная война',
#  'И время как вода',
#  'Он не сошел с ума',
#  'Ты ничего не знала',
#  'Полковнику никто не пишет',
#  'Полковника никто не ждет',
#  'На линии огня',
#  'Пустые города',
#  'В которых никогда',
#  'Ты раньше не бывала',
#  'И рвутся поезда',
#  'На тонкие слова',
#  'Я сижу и смотрю в чужое небо из чужого окна',
#  'И не вижу ни одной знакомой звезды.',
#  'Я ходил по всем дорогами туда, и сюда,',
#  'Обернулся - и не смог разглядеть следы.',
#  'Но если есть в кармане пачка сигарет,',
#  'Значит все не так уж плохо на сегодняшний день.',
#  'И билет на самолет с серебристым крылом,',
#  'Что, взлетая, оставляет земле лишь тень.',
#  'И никто не хотел быть виноватым без вина,',
#  'И никто не хотел руками жар загребать,',
#  'А без музыки на миру смерть не красна,',
#  'А без музыки не хочется пропадать.',
#  'Призрачно все в этом мире бушующем,',
#  'Есть только миг - за него и держись.',
#  'Есть только миг между прошлым и будущим,-',
#  'Именно он называется жизнь.',
#  'Вечный покой сердце вряд ли обрадует,',
#  'Вечный покой - для седых пирамид.',
#  'А для звезды, что сорвалась и падает',
#  'Есть только миг, ослепительный миг.',
#  'Пусть этот мир в даль летит сквозь столетия,',
#  'Но не всегда по дороге мне с ним,',
#  'Чем дорожу, чем рискую на свете я?',
#  'Мигом одним, только мигом одним.',
#  'Счастье дано повстречать иль беду еще',
#  'Есть только миг - за него и держись!',
#  'Волки уходят в небеса.',
#  'Горят холодные глаза.',
#  'Приказа верить в чудеса',
#  'Не поступало.',
#  'И каждый день другая цель,',
#  'То стены гор, то горы стен',
#  'И ждёт отчаянных гостей',
#  'Чужая стая.',
#  'Спиной,',
#  'К ветру и всё же',
#  'Вырваться может',
#  'Чья-то душа.',
#  'Спасёт,',
#  'Но не поможет',
#  'Чувствую кожей,',
#  'Пропащая.',
#  'Не помнят слов, не видят снов',
#  'Переросли своих отцов.',
#  'И, кажется, рука бойцов',
#  'Колоть устала.',
#  'Позор и слава в их крови',
#  'Хватает смерти и любви',
#  'Но сколько волка не корми',
#  'Ему все мало.',
#  'Волки уходят,',
#  'Волки уходят...',
#  'Всё из чего мои сомнения сотканы, тонко.',
#  'Какой чудесный день, моя струится лень',
#  'На грани просветления',
#  'Сияет шамбала и нежится душа',
#  'В нирване воскресения.',
#  'О, как легко мои воспоминания выцвели',
#  'Кто я такой и почему сбиваются мысли.',
#  'Верхом на звезде,',
#  'Вцепившись в лучи,',
#  'Слуной на поводке',
#  'В ночи',
#  'Верхом на звезде',
#  'Несусь на встречу ветрам,',
#  'К не сбывшейся мечте',
#  'И снам',
#  'О, жизнь, ты прекрасна,',
#  'О, жизнь, ты прекрасна вполне.',
#  'Бываешь немного опасна. О-е.',
#  'Возьмимое сердце,',
#  'Храни, вспоминай обо мне,',
#  'Поверь мне, что все не напрасно.',
#  'Над лесом, рекой,',
#  'Потерян навсегда',
#  'Покой.',
#  'Верхом на звезде.',
#  'Mit ornodi abolo esta.',
#  'Билет в один конец—',
#  'Весна',
#  'И создал этот мир',
#  'Я сам',
#  'Верь мне …',
#  'Я маленькая лошадка',
#  'И мне живётся не сладко',
#  'Мне трудно нести мою ношу',
#  'Настанет день, и я её брошу',
#  'Но стою очень много денег',
#  'И я везу свою большую повозку',
#  'С того на этот берег',
#  'Мне хочется плакать, мне хочется смеяться',
#  'Мне хочется прыгать, валяться и брыкаться',
#  'Чтобы были друзья или, хотя бы один',
#  'Но я работаю, как вол, в моей тележке кокаин',
#  'Я умру очень рано, и я знаю об этом',
#  'Может быть невесной, может быть ранним летом',
#  'Я люблю слушать песни, и костра нюхать дым',
#  'Но нельзя мне отвлекаться, я везу кокаин',
#  'Я устала ужасно, я хочу отдохнуть',
#  'Съесть мешко в десять сена и на долго уснуть',
#  'Я хочу к перелётным птицам вклиниться в клин',
#  'Но работа важней, за спиной кокаин',
#  'Мне противно и трудно, но нельзя отступить',
#  'Хоть и хочется есть, хоть и хочется пить',
#  'Мы когда-нибудь за это в адском пламени сгорим',
#  'Но всё это потом, а в данный момент кокаин',
#  'Мне обидно, и капают слёзы',
#  'Когда мне под ноги кидают розы',
#  'Когда люди на улицах и в окнах квартир',
#  'Меня встречают и устраивают пир на весь мир',
#  'Мне рады даже малые дети',
#  'Мне машут даже деревьев ветви',
#  'Меня приветствуют все, все, как один',
#  'Я привезла им новый мир',
#  'Я при везла кокаин',
#  'Впилась занозой в сердце мое стрела Купидона',
#  'Хочется вытащить и никогда не думать об этом',
#  'Боль нестерпима и м недосих пор была незнакома',
#  'Солнце безжалостно выжгло глаза своим ярким светом',
#  'Одна она повсюду, где бы не скрылся я',
#  'Во всех глазах и лицах только одна она',
#  'Больше нет места, где бы я мог зализывать раны',
#  'Крылья разбиты и тело моево власти гангрены',
#  'Сил больше нет, нет сна, лишь страх постоянный',
#  'Лишь голоствой в моей голове и белые стены',
#  'Лишь одна она',
#  'Впилось занозой в сердце мое стрела Купидона',
#  'Злобный уродецникак не оставит в покое',
#  'Пусть будет больно, силы найду и выдерну с корнем',
#  'Новая жизнь. Нужно понять, что это такое',
#  'Лишь она',
#  'Жизнь иногда выпускает жало',
#  'Стирая прошлое, словно вирус',
#  'И к хоккеисту жена сбежала',
#  'И на работе полнеший минус',
#  'Но наш герой – не сдаётся',
#  'Слезы утри,',
#  'Пожизни идёт и смеётся',
#  'Вот он, смотри',
#  'Он самый счастливый из нас',
#  'Избранный небесами',
#  'Он Вам – не старый баркас',
#  'Афрегат с парусами',
#  'В чём же причина тогда?',
#  'Три обычные строчки',
#  'Ждут его дома всегда',
#  'Его папины дочки',
#  'Он помогает добрым советом',
#  'И мудрым словом он лечит души',
#  'На все вопросы, он знает ответы',
#  'Всегда подскажет, как сделать лучше',
#  'А что его ждёт впереди?',
#  'Там всё не так гладко',
#  'Но всё же он победит',
#  'Парень – загадка',
#  'Помину там осыпается',
#  'Ожидание невозможного',
#  'Ранним утром просыпается',
#  'Отдвижения неосторожного.',
#  'Как молчание ледяной зимы',
#  'Нас закутало неизвестностью,',
#  'Здесь так долго друг друга искали мы,',
#  'И, конечно, пропали без вести',
#  'Простится',
#  'Нетусил, закрываю,',
#  'Я глаза закрываю,',
#  'Сквозь туман уплываю',
#  'По аллеям столицы',
#  'За потерей потеря',
#  'И года полетели',
#  'За дождями метели',
#  'Перелетные птицы',
#  'Только ночью не могу уснуть',
#  'Странный холод в сердце прячется',
#  'Что случилось?– скажи темне кто-нибудь',
#  'Только осень в окномне расплачется',
#  'В подоконник мой бьются горошины',
#  'Тишину, разбивая весельем,',
#  'Умирали давно понемножку мы',
#  'И, наверное, было спасение',
#  'Время смотрит спокойно с презрением',
#  'Вы меня уже верно не вспомните',
#  'Опоздавшее ходит прозрение',
#  'По моей гладко выбритой комнате',
#  'Не досказано и недослушенно',
#  'Сердце бьется другими вершинами',
#  'Значит все безнадежно разрушено,',
#  'Ну зачем же, зачем поспешили мы',
#  'Помню, помню я как мы встретились с тобою',
#  'Был конец дня, ты спросила у меня сигареточку',
#  'Я подумал, что за фигня',
#  'Сигаретка осталась всего одна, ну ладно на...',
#  'Мы прожили пятнадцать лет',
#  'Но вот теперь ты ушла тебя нет.',
#  'Но ты ушла в своем оранжевом плаще',
#  'Ну ты даешь вообще, ну ты даешь вообще блин!',
#  'Но ты ушла и не сказала: я скоро вернусь',
#  'Чёже ты делаешь Люсь, как-же я буду один',
#  'Помню, помню я как по улице весенний,',
#  'Я с тобой гулял, мы купили банку пива и двух лещей',
#  'Ты была молода - красива,',
#  'И похожа на апельсина в своем новом плаще',
#  'И я любил тебя как свою, вот и теперь о тебе я пою!',
#  'Помню, помню, как я дарил тебе, что попросишь',
#  'Но какой же дурак я был, если-б знал, что ты меня бросишь',
#  'Сэкономил бы, и я любил тебя обожал',
#  'Ну а ты мне в спину кинжал, ох не сладко мне',
#  'Я пригрел на груди змею, вот и теперь о тебе я пою!',
#  'Я смотрю на тебя,',
#  'В телевизоре ты, а я на диване.',
#  'В городе N дожди,',
#  'Замыкание+ бах! и встали трамваи',
#  'Травма черепно-мозговая моя любовь!',
#  'По-по-по на конаплю, и к тебе доплыву, долечу, доеду',
#  'Рядом с тобой поселюсь, ты будешь рада такому соседу!',
#  'Мы из России народ простой, я те сразу скажу Здорово!',
#  'А ты улыбнёшься и скажешь мне Я так ждала тебя, Вова!',
#  'Я так ждала тебя, Вова!',
#  'В телевизоре ты, а я на диване',
#  'В городе N зима,',
#  'Скоро выходы все и входы завалит',
#  'Ну я приду без крика, без шума,',
#  'Ну найду какой-нибудь повод,',
#  'Скажу Ну здравствуй, Ума,',
#  'Она скажет Ну здравствуй, Вова.',
#  'Ну надо как-то отношения завязывать',
#  'Я скажу Ну как ты тут вообще жива здорова-то?',
#  "Она скажет:'А, вообще, Володька, хреново!'",
#  'И начнёт рассказывать.',
#  'Вот, - скажет, - вчера, к примеру, приходил Тарнтино',
#  'Нажрался, говорит, и стал приставать ко мне, здоровенная детина.',
#  'Я тогда ему так строго сказала Квентин!',
#  'Может, ты конечно, говорит, и не заметил,',
#  'Но вообще-то я жду Володьку из России,',
#  'А тебя, говорит, вообще заходить не просили',
#  'Вот такая батва, прикинь?',
#  'Бывает не до смеха',
#  'В общем, было трудно без тебя, Вован.',
#  'Хорошо, что приехал',
#  'Жил-был на свете Антон Городецкий,',
#  'Бросила жена, он грустил не по-детски.',
#  "Пришёл к колдунье:'Ану-ка наколдуй мне!'",
#  "'Легко, мой хороший, только хлопну в ладоши,",
#  'И жена вернётся, оттого отвернётся,',
#  "И маленькая жизнь внутри неё оборвётся.'",
#  'Но вдруг налетели на ведьму тени',
#  "Привидений, говорят:'Не бывать преступленью'",
#  'Ну что же ты, что ты потупила взор?',
#  'Сдавайся, ведьма– «Ночной Дозор».',
#  'И треснул мир на пополам, дымит разлом,',
#  'И льётся кровь, идёт вой надобрасо злом.',
#  'Имеркнет свет, в углах паук плетё тузор,',
#  'Потёмным улицам летит «ночной дозор».',
#  'И понял Антоха, что поступил плохо,',
#  'И то, что развела его колдунья, как лоха.',
#  'Но сила «иного» в антоновом взоре,',
#  'А значит, он будет работать в «дозоре».',
#  'Годы прошли, Городецкий не тужит,',
#  'Водочку глушит, с вампирами дружит.',
#  'Начальник хороший – мудрейший Гесер',
#  'Был зам.министром in USSR.',
#  'Но вот вызывают, нужно ехать скорее,',
#  'Вампир-парикмахер с подружкой своею',
#  'В логово к себе заманили подростка,',
#  'Решили поужинать подло и просто.',
#  'Антоха успел, завязалась драка,',
#  'С огромным трудом, но всё ж убил вурда лака,',
#  'Ножницами был тяжело ранен в бою,',
#  'При смерти был, можно сказать на краю.',
#  'Но добрый Гесер его вылечил быстро,',
#  'Еще бы, абы кого не берут в замминистры.',
#  'А дальше - беда за бедой, как по нотам:',
#  'Ворона залетела в турбину самолёта,',
#  'На тепло централи чего-то взорвалось,',
#  'А Света виновна во всём оказалась,',
#  'Но, встретив красавца Антона, влюбилась,',
#  'И разрушение остановилось.',
#  'Но злой Завулон из «дозора дневного»',
#  'Сделал из сына Антона «иного».',
#  'И как с этим справится наш герой?',
#  'Все на просмотр картины второй!',
#  'В газетах писали, что ты уезжаешь,',
#  'Что рейс не отменят, что рейс не отложат.',
#  'Какие-то люди тебя окружают,',
#  'А ближе, чем были - уже не возможно.',
#  'В красивых журналах считают пунктиры,',
#  'А я - до квартиры вечернее сальто.',
#  'И кривятся губы, и кофе противен,',
#  "И новое утро, и новое 'нет тебя...'",
#  'Я по асфальту шагаю',
#  'С тем, кого сберечь не смогу.',
#  'До остановки трамвая,',
#  'Звенящего на бегу.',
#  'В газетах писали, что ты - идиотка,',
#  'Во всём виновата проклятая водка.',
#  'Ругаешься матом, и песен не пишешь,',
#  'Тебя окружают не люди, а мыши.',
#  'Такое не выдумать даже нарошно.',
#  'А я каждый вечер ползу до квартиры,',
#  'И ближе, чем были - уже не возможно.',
#  'Измученный дорогой, я выбился из сил.',
#  'И в доме лесникая ночлега попросил.',
#  'С улыбкой добродушной старик меня впустил.',
#  'И жестом дружелюбным на ужин пригласил.',
#  'Будь как дома, путник, я ни в чём не откажу,',
#  'Я ни в чем не откажу, я ни в чём не откажу!',
#  'Множество историй, коль желаешь, расскажу,',
#  'Коль желаешь, расскажу,',
#  'Коль желаешь, расскажу!',
#  'На улице темнело, сиделя за столом.',
#  'Лесник сидел напротив, болтал о том, о сём.',
#  'Что нет среди животных у старика врагов,',
#  'Что нравится ему подкармливать волков.',
#  'И волки среди ночи завыли под окном.',
#  'Старик заулыбался и вдруг покинул дом.',
#  'Но вскоре возвратился с ружьём на перевес:',
#  "'Друзья хотят покушать, пойдём, приятель, в лес!'",
#  'Я шёл к себе домой',
#  'Я шёл по мокрым лужам',
#  'По скользкой мостовой',
#  'Ногами снег утюжил',
#  'А мокрый снег падал',
#  'А я шёл домой',
#  'По зимнему саду',
#  'По пустой мостовой',
#  'Он шёл со мной рядом',
#  'Шпионил за мной',
#  'Следил за мной взглядом',
#  'Бесшумный конвой',
#  'И вот я стою',
#  'На краю снего пада',
#  'С неба падает снег',
#  'Значит небу так надо',
#  'В это трудно поверить',
#  'Я вернулся домой',
#  'Ты открыла мне двери',
#  'Снег вошёл вслед за мной',
#  'И вдруг снег растаял',
#  'Увидел тебя',
#  'На пороге остались',
#  'Только капли дождя',
#  'Нас уносит река',
#  'Плавных вёсел волнами',
#  'Словно кто-то открыл',
#  'Все небесные краны',
#  'Мы стоим на краю',
#  'На краю водопада',
#  'С неба льётся вода',
#  'За морями есть лимо новый сад',
#  'Я найду лимони буду рад',
#  'Но тебе не дам не смей меня винить',
#  'Посмотрите до чего он хорош',
#  'Но на дороге ты его не найдешь',
#  'Попробуй сделай сам не буду я тебя учить',
#  'Растут лимоны на высоких горах',
#  'На крутых берегах для крутых',
#  'Короче ты не достанешь',
#  'Я вижу цель я за лимоном дотянуться хочу',
#  'Я за лимоном лечу и крутизной наслаждаюсь',
#  'Страна Лимония страна без забот',
#  'В страну Лимонию ведет подземный ход',
#  'Найти попробуй сам не буду я тебя учить',
#  'Трудна дорога и повсюду обман',
#  'Но чтоб не сбиться у меня есть план',
#  'Но я тебе не дам не смей меня винить',
#  'Страну Лимонию ищу с давних пор',
#  'Мне надоел вечно зеленый помидор',
#  'Его ты кушай сам не смей его со мной делить',
#  'Не смей его со мной делить',
#  'Выйду на улицу - солнца нема,',
#  'Парни молодые свели меня с ума.',
#  'Выйду на улицу, гляну на село,-',
#  'Девки гуляют, и мне весело.',
#  'Матушка родная, водицы мне дай,',
#  'Сердце мое так и кидает в жар.',
#  'Раньше я гуляла в зеленом саду,',
#  'Думала на улицу век не пойду.',
#  'А теперь под вечераж пятки горят-',
#  'Ноженьки резвые в пляску хотят.',
#  'Я пойду на улицу, к девкам пойду,',
#  'Голосом звонким я им подпою.',
#  'Матушка, слышишь, соловушек поет,',
#  'А там, под горою, пляска идет-',
#  'Девки голосистые звонко поют,',
#  'Мне да молоденькой спать не дают.',
#  'Теплое место, но улицы ждут',
#  'Отпечатко в наших ног.',
#  'Звездная пыль - на сапогах.',
#  'Мягкое кресло, клетчатый плед,',
#  'Не нажатый во время курок.',
#  'Солнечный день - восле пительных снах.',
#  'Группа крови - на рукаве,',
#  'Мой порядковый номер - на рукаве,',
#  'Пожелай мне удачи в бою, пожелай мне:',
#  'Не остаться в этой траве,',
#  'Не остаться в этой траве.',
#  'Пожелай мне удачи, пожелай мне удачи!',
#  'И есть чем платить, но я не хочу',
#  'Победы любой ценой.',
#  'Я никому не хочу ставить ногу на грудь.',
#  'Я хотел бы остаться с тобой,',
#  'Просто остаться с тобой,',
#  'Но высокая вне бе звезда зовет меня в путь.',
#  'Ночь коротка, цель далека,',
#  'Ночью так часто хочется пить,',
#  'Ты выходишь на кухню,',
#  'Но вода здесь горька,',
#  'Ты не можешь здесь спать,',
#  'Ты не хочешь здесь жить.',
#  'Доброе утро, последний герой!',
#  'Доброе утро тебе и таким, как ты,',
#  'Доброе утро, последний герой.',
#  'Здравствуй, последний герой!',
#  'Ты хотел быть один, это быстро прошло,',
#  'Ты хотел быть один, но не смог быть один,',
#  'Твоя ноша легка, но немеет рука,',
#  'И ты встречаешь рассвет за игрой в дурака.',
#  'Утром ты стремишься скорее уйти,',
#  "Телефонный звонок, как команда 'Вперед!'",
#  'Ты уходишь туда, куда не хочешь идти,',
#  'Ты уходишь туда, но тебя там никто не ждет!',
#  'Я иду по улице в зеленом пиджаке.',
#  'Мне нравятся мои ботинки.',
#  'А еще красивый галстук у меня.',
#  'Я гладил брюки два часа,',
#  'В парикмахерской сидел с утра.',
#  'И вот иду я по улице, один я.',
#  'По улице иду я.',
#  'По улице один.',
#  'У моего приятеля есть новые пластинки.',
#  'И я зайду в кафе и выпью чашку кофе.',
#  'А потом пойду к нему.',
#  'И в зеркалах витрин я так похож на Боди Холи.',
#  'Папа скоро даст свою машину покататься мне.',
#  'Иду я.',
#  'По улице один я.',
#  'Иду я по улице один.',
#  'Весна - постоянный насморк.',
#  'Весна - солнце светит опять.',
#  'И я промочил ноги.',
#  'Весна - и я опять иду гулять.',
#  'Весна - я не могу усидеть дома.',
#  'Весна - я люблю весну.',
#  'О чем поют в моем дворе кошки?',
#  'Нет - нет - нет - нет,',
#  ...]

# %%
def get_space_positions(no_space_text, spaced_text):
    """
    Возвращает индексы символов в строке без пробелов,
    после которых должны стоять пробелы в строке с пробелами.

    Принимает:
        no_space_text (str): строка без пробелов
        spaced_text (str): строка с пробелами

    Возвращает:
        list[int]: список индексов символов (по строке без пробелов),
                   после которых в исходной строке встречался пробел.

    Пример:
        >>> get_space_positions("helloworld", "hello world")
        [4]
        # потому что пробел стоит после символа "t" (индекс 4)
    """
    positions = []
    j = 0
    for char in spaced_text:
        if char == " ":
            positions.append(j - 1)  # пробел после предыдущего символа
        else:
            j += 1
    return positions


test_df["predicted_positions"] = test_df.apply(
    lambda row: get_space_positions(row["text"], row["text_spaces"]), axis=1
)

# %% [markdown]
# Добавим +1 для корректности принятия решения

# %%
test_df["predicted_positions"] = test_df["predicted_positions"].apply(
    lambda lst: [x + 1 for x in lst] if isinstance(lst, list) else lst
)

# %%
test_df.head()
# Out:
#   id                           text                         text_spaces  \
# 0  0                куплюайфон14про                  куплю айфон 14 про
# 1  1             ищудомвПодмосковье               ищу дом в Подмосковье
# 2  2  сдаюквартирусмебельюитехникой  сдаю квартиру с мебелью и техникой
# 3  3     новыйдивандоставканедорого       новый диван доставка недорого
# 4  4                отдамдаромкошку                   отдам даром кошку
#
#              space_pos  predicted_positions
# 0          [5, 11, 14]          [5, 10, 12]
# 1            [3, 7, 9]            [3, 6, 7]
# 2  [4, 13, 15, 23, 25]  [4, 12, 13, 20, 21]
# 3          [5, 11, 20]          [5, 10, 18]
# 4              [5, 11]              [5, 10]

# %%
test_df["predicted_positions"] = test_df["predicted_positions"].apply(lambda x: str(x) if isinstance(x, list) else x)

# %%
type(test_df['predicted_positions'][1])
# Out:
# str

# %%
test_df.head()
# Out:
#   id                           text                         text_spaces  \
# 0  0                куплюайфон14про                  куплю айфон 14 про
# 1  1             ищудомвПодмосковье               ищу дом в Подмосковье
# 2  2  сдаюквартирусмебельюитехникой  сдаю квартиру с мебелью и техникой
# 3  3     новыйдивандоставканедорого       новый диван доставка недорого
# 4  4                отдамдаромкошку                   отдам даром кошку
#
#              space_pos  predicted_positions
# 0          [5, 11, 14]          [5, 10, 12]
# 1            [3, 7, 9]            [3, 6, 7]
# 2  [4, 13, 15, 23, 25]  [4, 12, 13, 20, 21]
# 3          [5, 11, 20]          [5, 10, 18]
# 4              [5, 11]              [5, 10]

# %% [markdown]
# Создаем submission

# %%
test_df[["id", "predicted_positions"]].to_csv("submission.csv", index=False, encoding="utf-8")

# %% [markdown]
# Функция для првоерок

# %%
test1 = test_df[['text']].copy()
test1.head()
# Out:
#                             text
# 0                куплюайфон14про
# 1             ищудомвПодмосковье
# 2  сдаюквартирусмебельюитехникой
# 3     новыйдивандоставканедорого
# 4                отдамдаромкошку

# %%
def your_tests(text_series: pd.Series):
  """
  Принимает:
      text_series (pd.Series): столбец с текстами без пробелов
      model: обученная модель
      tokenizer: токенизатор

  Возвращает:
      pd.DataFrame с колонками:
        - text: исходный текст без пробелов
        - text_spaces: текст с восстановленными пробелами
        - predicted_positions: индексы символов (+1), после которых предсказан пробел
        - space_pos: индексы реальных пробелов в восстановленном тексте
  """
  df = pd.DataFrame({"text": text_series.copy()})

  df['text_spaces'] = [
      restore_spaces(text, model, tokenizer, device=device)
      for text in tqdm(df['text'], desc="Restoring spaces")]

  df["predicted_positions"] = df.apply(
      lambda row: get_space_positions(row["text"], row["text_spaces"]), axis=1)

  df["predicted_positions"] = df["predicted_positions"].apply(
      lambda lst: [x + 1 for x in lst] if isinstance(lst, list) else lst)

  df['space_pos'] = df['text_spaces'].apply(get_space_indices)

  return df

# %%
test1 = your_tests(test1["text"])
# Out:
# Restoring spaces: 100%|██████████| 1005/1005 [00:15<00:00, 66.51it/s]

# %%
test1.head()
# Out:
#                             text                         text_spaces  \
# 0                куплюайфон14про                  куплю айфон 14 про
# 1             ищудомвПодмосковье               ищу дом в Подмосковье
# 2  сдаюквартирусмебельюитехникой  сдаю квартиру с мебелью и техникой
# 3     новыйдивандоставканедорого       новый диван доставка недорого
# 4                отдамдаромкошку                   отдам даром кошку
#
#    predicted_positions            space_pos
# 0          [5, 10, 12]          [5, 11, 14]
# 1            [3, 6, 7]            [3, 7, 9]
# 2  [4, 12, 13, 20, 21]  [4, 13, 15, 23, 25]
# 3          [5, 10, 18]          [5, 11, 20]
# 4              [5, 10]              [5, 11]
